# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]='/Users/phillliprashaad/Google_API_Key.json'

# %%
import bq_helper
from bq_helper import BigQueryHelper
# https://www.kaggle.com/sohier/introduction-to-the-bq-helper-package
medicare = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="cms_medicare")

# %%
bq_assistant = BigQueryHelper("bigquery-public-data", "cms_medicare")

# %%
#The code below list all the tables contained in this database. There are 23 tables
bq_assistant.list_tables()
# Out:
# ['home_health_agencies_2013',
#  'home_health_agencies_2014',
#  'hospice_providers_2014',
#  'hospital_general_info',
#  'inpatient_charges_2011',
#  'inpatient_charges_2012',
#  'inpatient_charges_2013',
#  'inpatient_charges_2014',
#  'inpatient_charges_2015',
#  'nursing_facilities_2013',
#  'nursing_facilities_2014',
#  'outpatient_charges_2011',
#  'outpatient_charges_2012',
#  'outpatient_charges_2013',
#  'outpatient_charges_2014',
#  'outpatient_charges_2015',
#  'part_d_prescriber_2014',
#  'physicians_and_other_supplier_2012',
#  'physicians_and_other_supplier_2013',
#  'physicians_and_other_supplier_2014',
#  'physicians_and_other_supplier_2015',
#  'referring_durable_medical_equip_2013',
#  'referring_durable_medical_equip_2014']

# %%
#I wanted to look at the 'part_d_prescriber_2014' table schema to get a better understand of the table layout
bq_assistant.table_schema('part_d_prescriber_2014')
# Out:
#                              name     type      mode  \
# 0                             npi   STRING  REQUIRED
# 1    nppes_provider_last_org_name   STRING  NULLABLE
# 2       nppes_provider_first_name   STRING  NULLABLE
# 3             nppes_provider_city   STRING  NULLABLE
# 4            nppes_provider_state   STRING  NULLABLE
# 5           specialty_description   STRING  NULLABLE
# 6                description_flag   STRING  NULLABLE
# 7                       drug_name   STRING  REQUIRED
# 8                    generic_name   STRING  NULLABLE
# 9                      bene_count  INTEGER  NULLABLE
# 10              total_claim_count  INTEGER  NULLABLE
# 11               total_day_supply  INTEGER  NULLABLE
# 12                total_drug_cost    FLOAT  NULLABLE
# 13                bene_count_ge65  INTEGER  NULLABLE
# 14  bene_count_ge65_suppress_flag   STRING  NULLABLE
# 15         total_claim_count_ge65  INTEGER  NULLABLE
# 16             ge65_suppress_flag   STRING  NULLABLE
# 17          total_day_supply_ge65  INTEGER  NULLABLE
# 18           total_drug_cost_ge65    FLOAT  NULLABLE
# 19        total_30_day_fill_count    FLOAT  NULLABLE
# 20   total_30_day_fill_count_ge65    FLOAT  NULLABLE
#
#                                           description
# 0                        National Provider Identifier
# 1         Last Name/Organization Name of the Provider
# 2                          First Name of the Provider
# 3                                City of the Provider
# 4                          State Code of the Provider
# 5                             Provider Specialty Type
# 6                        Source of Provider Specialty
# 7                                    Name of the drug
# 8                            Generic name of the drug
# 9                    Number of Medicare Beneficiaries
# 10  Number of Medicare Part D Claims, Including Re...
# 11              Number of Day's Supply for All Claims
# 12                 Aggregate Cost Paid for All Claims
# 13           Number of Medicare Beneficiaries Age 65+
# 14          Reason for Suppression of Bene_Count_ge65
# 15  Number of Claims, Including Refills, for Benef...
# 16  Reason for Suppression of Total_Claim_Count_Ge...
# 17  Number of Day's Supply for All Claims for Bene...
# 18  Aggregate Cost Paid for All Claims for Benefic...
# 19  The aggregate number of Medicare Part D standa...
# 20  The number of Medicare Part D standardized 30-...

# %%
#I am looking at the first 15 records of table 'part_d_prescriber_2014' in a Pandas DataFrame
bq_assistant.head('part_d_prescriber_2014', num_rows=15)
# Out:
#            npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0   1003002817                     IGLESIAS                    NAYVIS
# 1   1003009218                        NOLEN                     JAMES
# 2   1003013756                        PHUNG                      ANDY
# 3   1003034851                         GUST                       AMY
# 4   1003070723                        BEARD                      MARK
# 5   1003096587                      IRIARTE                  MANRIQUE
# 6   1003243544                    MCDONNELL                   KATHRYN
# 7   1003803321                       TURNER                   KENNETH
# 8   1003803552                        TOWNE                   WILLIAM
# 9   1003806621                    DESANTOLA                    JOSEPH
# 10  1003809963                     REXINGER                   KENNETH
# 11  1003810037                        MUNIZ                  LEOPOLDO
# 12  1003813114                       SLAWEK                     DAVID
# 13  1003814146                        PATEL                     KETAN
# 14  1003816281                        GREER                  JONATHAN
#
#    nppes_provider_city nppes_provider_state specialty_description  \
# 0                DORAL                   FL       Family Practice
# 1            MORRILTON                   AR       Family Practice
# 2               LENOIR                   NC       Family Practice
# 3          SEVIERVILLE                   TN       Family Practice
# 4           SOUTHFIELD                   MI       Family Practice
# 5       PEMBROKE PINES                   FL     Internal Medicine
# 6         POUGHKEEPSIE                   NY    Nurse Practitioner
# 7         RUSSELLVILLE                   AR       Family Practice
# 8               GENEVA                   IL            Cardiology
# 9       HENDERSONVILLE                   NC     Internal Medicine
# 10        SAN CLEMENTE                   CA     Internal Medicine
# 11               AIKEN                   SC       Family Practice
# 12      HENDERSONVILLE                   NC     Internal Medicine
# 13              DALLAS                   TX     Internal Medicine
# 14       BOYNTON BEACH                   FL          Rheumatology
#
#    description_flag                      drug_name  \
# 0                 S                     CILOSTAZOL
# 1                 S                      LORAZEPAM
# 2                 S                    ALLOPURINOL
# 3                 S                    ALLOPURINOL
# 4                 S      HYDROCODONE-ACETAMINOPHEN
# 5                 S                   GLIPIZIDE XL
# 6                 S                     GABAPENTIN
# 7                 S                      MELOXICAM
# 8                 S                    SIMVASTATIN
# 9                 S            AMLODIPINE BESYLATE
# 10                S  VALSARTAN-HYDROCHLOROTHIAZIDE
# 11                S                     GABAPENTIN
# 12                S                 SERTRALINE HCL
# 13                S                  CLONIDINE HCL
# 14                S                     GABAPENTIN
#
#                      generic_name  bene_count  ...  total_day_supply  \
# 0                      CILOSTAZOL        14.0  ...              4020
# 1                       LORAZEPAM        26.0  ...              2900
# 2                     ALLOPURINOL        14.0  ...              3540
# 3                     ALLOPURINOL        21.0  ...              4844
# 4       HYDROCODONE/ACETAMINOPHEN        65.0  ...              6654
# 5                       GLIPIZIDE         NaN  ...              1303
# 6                      GABAPENTIN        23.0  ...              2244
# 7                       MELOXICAM        42.0  ...              6689
# 8                     SIMVASTATIN        13.0  ...              2550
# 9             AMLODIPINE BESYLATE        30.0  ...              6305
# 10  VALSARTAN/HYDROCHLOROTHIAZIDE        14.0  ...              3596
# 11                     GABAPENTIN        61.0  ...              8514
# 12                 SERTRALINE HCL        23.0  ...              5512
# 13                  CLONIDINE HCL        37.0  ...              2191
# 14                     GABAPENTIN        27.0  ...              5645
#
#     total_drug_cost  bene_count_ge65  bene_count_ge65_suppress_flag  \
# 0           1428.25              NaN                              #
# 1            827.61             14.0                           None
# 2            707.65              NaN                              *
# 3            849.56              NaN                              #
# 4           6399.23             36.0                           None
# 5            513.84              NaN                              *
# 6            966.51              NaN                              #
# 7           1042.49              NaN                              #
# 8            502.81             13.0                           None
# 9            798.13              NaN                              #
# 10          4558.19             14.0                           None
# 11          4520.28              NaN                              #
# 12          1109.93             23.0                           None
# 13           634.61              NaN                              #
# 14          4258.02              NaN                              #
#
#    total_claim_count_ge65  ge65_suppress_flag total_day_supply_ge65  \
# 0                     110                None                  3450
# 1                      56                None                  1250
# 2                      42                None                  2280
# 3                      84                None                  3944
# 4                     147                None                  3273
# 5                      41                None                  1303
# 6                      39                None                  1224
# 7                     136                None                  4460
# 8                      39                None                  2550
# 9                      88                None                  4985
# 10                     82                None                  3596
# 11                    245                None                  8108
# 12                     99                None                  5512
# 13                     59                None                  1517
# 14                     86                None                  4080
#
#     total_drug_cost_ge65  total_30_day_fill_count  \
# 0                1278.20                    134.0
# 1                 464.61                    116.1
# 2                 399.14                    118.0
# 3                 662.59                    162.0
# 4                3046.12                    275.2
# 5                 513.84                     43.4
# 6                 532.80                     75.0
# 7                 660.38                    235.0
# 8                 502.81                     85.0
# 9                 643.78                    211.0
# 10               4558.19                    120.0
# 11               4324.27                    335.7
# 12               1109.93                    186.0
# 13                411.03                    101.0
# 14               3122.29                    189.0
#
#     total_30_day_fill_count_ge65
# 0                          115.0
# 1                           56.1
# 2                           76.0
# 3                          132.0
# 4                          149.1
# 5                           43.4
# 6                           41.0
# 7                          160.0
# 8                           85.0
# 9                          167.0
# 10                         120.0
# 11                         313.7
# 12                         186.0
# 13                          77.0
# 14                         136.0
#
# [15 rows x 21 columns]

# %%
#What states has the most overall prescriptions?
#Assumption: States with larger populations will have more prescriptions

query1 = """SELECT
  nppes_provider_state AS state,
  ROUND(SUM(total_claim_count) / 1e6) AS total_claim_count_millions
FROM
  `bigquery-public-data.cms_medicare.part_d_prescriber_2014`
GROUP BY
  state
ORDER BY
  total_claim_count_millions DESC
;
        """
response1 = medicare.query_to_pandas_safe(query1)
response1.head(51)
# Out:
#    state  total_claim_count_millions
# 0     CA                       116.0
# 1     FL                        91.0
# 2     NY                        80.0
# 3     TX                        76.0
# 4     PA                        63.0
# 5     OH                        53.0
# 6     NC                        46.0
# 7     IL                        43.0
# 8     MI                        39.0
# 9     GA                        39.0
# 10    TN                        35.0
# 11    MO                        31.0
# 12    NJ                        29.0
# 13    IN                        28.0
# 14    KY                        26.0
# 15    VA                        26.0
# 16    MA                        26.0
# 17    AL                        26.0
# 18    PR                        25.0
# 19    SC                        22.0
# 20    LA                        22.0
# 21    WI                        21.0
# 22    AZ                        20.0
# 23    WA                        19.0
# 24    MN                        17.0
# 25    MS                        16.0
# 26    AR                        16.0
# 27    IA                        15.0
# 28    OK                        15.0
# 29    MD                        14.0
# 30    OR                        14.0
# 31    CO                        13.0
# 32    CT                        13.0
# 33    KS                        12.0
# 34    WV                        11.0
# 35    NE                         8.0
# 36    NV                         7.0
# 37    NM                         6.0
# 38    UT                         6.0
# 39    RI                         6.0
# 40    ME                         6.0
# 41    ID                         5.0
# 42    SD                         4.0
# 43    HI                         4.0
# 44    NH                         4.0
# 45    ND                         3.0
# 46    MT                         3.0
# 47    DE                         3.0
# 48    VT                         2.0
# 49    AK                         1.0
# 50    WY                         1.0

# %%
#Set python variable equal to query
max_presc_by_state = response1.head(51).copy()

# %%
max_presc_by_state.set_index('state', inplace=True)

# %%
max_presc_by_state
# Out:
#        total_claim_count_millions
# state
# CA                          116.0
# FL                           91.0
# NY                           80.0
# TX                           76.0
# PA                           63.0
# OH                           53.0
# NC                           46.0
# IL                           43.0
# MI                           39.0
# GA                           39.0
# TN                           35.0
# MO                           31.0
# NJ                           29.0
# IN                           28.0
# KY                           26.0
# VA                           26.0
# MA                           26.0
# AL                           26.0
# PR                           25.0
# SC                           22.0
# LA                           22.0
# WI                           21.0
# AZ                           20.0
# WA                           19.0
# MN                           17.0
# MS                           16.0
# AR                           16.0
# IA                           15.0
# OK                           15.0
# MD                           14.0
# OR                           14.0
# CO                           13.0
# CT                           13.0
# KS                           12.0
# WV                           11.0
# NE                            8.0
# NV                            7.0
# NM                            6.0
# UT                            6.0
# RI                            6.0
# ME                            6.0
# ID                            5.0
# SD                            4.0
# HI                            4.0
# NH                            4.0
# ND                            3.0
# MT                            3.0
# DE                            3.0
# VT                            2.0
# AK                            1.0
# WY                            1.0

# %%
#Now lets plot our results

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
max_presc_by_state.sort_values('total_claim_count_millions',inplace=True)
max_presc_by_state.plot.barh(rot=-30, subplots=True,figsize =(10,15), position=.9 );

# %%
#How many distinct medications are in this table?

RXquery = """SELECT COUNT (DISTINCT drug_name) AS distinct_drugs
FROM `bigquery-public-data.cms_medicare.part_d_prescriber_2014`

        """
response3 = medicare.query_to_pandas_safe(RXquery, max_gb_scanned=10)
response3.head(51)
# Out:
#    distinct_drugs
# 0            2703

# %%
#STOP PLACE
#What is the most prescribed medication in each state?

query2 = """SELECT
  A.state,
  drug_name,
  total_claim_count,
  day_supply,
  ROUND(total_cost_millions) AS total_cost_millions
FROM (
  SELECT
    generic_name AS drug_name,
    nppes_provider_state AS state,
    ROUND(SUM(total_claim_count)) AS total_claim_count,
    ROUND(SUM(total_day_supply)) AS day_supply,
    ROUND(SUM(total_drug_cost)) / 1e6 AS total_cost_millions
  FROM
    `bigquery-public-data.cms_medicare.part_d_prescriber_2014`
  GROUP BY
    state,
    drug_name) A
INNER JOIN (
  SELECT
    state,
    MAX(total_claim_count) AS max_total_claim_count
  FROM (
    SELECT
      nppes_provider_state AS state,
      ROUND(SUM(total_claim_count)) AS total_claim_count
    FROM
      `bigquery-public-data.cms_medicare.part_d_prescriber_2014`
    GROUP BY
      state,
      generic_name)
  GROUP BY
    state) B
ON
  A.state = B.state
  AND A.total_claim_count = B.max_total_claim_count
ORDER BY
  A.total_claim_count DESC
;
        """
response2 = medicare.query_to_pandas_safe(query2, max_gb_scanned=10)
response2.head(51)
# Out:
#    state                  drug_name  total_claim_count   day_supply  \
# 0     CA       LEVOTHYROXINE SODIUM          3844722.0  211726348.0
# 1     FL       LEVOTHYROXINE SODIUM          2982449.0  163379911.0
# 2     TX  HYDROCODONE/ACETAMINOPHEN          2833795.0   60404796.0
# 3     NY        AMLODIPINE BESYLATE          2609790.0  123221634.0
# 4     PA       LEVOTHYROXINE SODIUM          2353753.0  109162406.0
# 5     OH       LEVOTHYROXINE SODIUM          1813810.0   93494247.0
# 6     MI  HYDROCODONE/ACETAMINOPHEN          1792522.0   39885683.0
# 7     NC       LEVOTHYROXINE SODIUM          1513777.0   68617909.0
# 8     IL       LEVOTHYROXINE SODIUM          1457499.0   74227568.0
# 9     TN  HYDROCODONE/ACETAMINOPHEN          1377467.0   29083360.0
# 10    GA        AMLODIPINE BESYLATE          1282226.0   54751806.0
# 11    AL  HYDROCODONE/ACETAMINOPHEN          1214392.0   26750604.0
# 12    PR       LEVOTHYROXINE SODIUM          1138257.0   39272134.0
# 13    MA                 LISINOPRIL          1126759.0   57560251.0
# 14    MO                 LISINOPRIL          1064933.0   50281198.0
# 15    IN  HYDROCODONE/ACETAMINOPHEN          1037564.0   21677166.0
# 16    KY  HYDROCODONE/ACETAMINOPHEN           983844.0   22278561.0
# 17    NJ       LEVOTHYROXINE SODIUM           959251.0   54068930.0
# 18    AZ       LEVOTHYROXINE SODIUM           866240.0   49734848.0
# 19    VA       LEVOTHYROXINE SODIUM           837399.0   42342428.0
# 20    LA  HYDROCODONE/ACETAMINOPHEN           795932.0   16274930.0
# 21    WA                 LISINOPRIL           771435.0   44262060.0
# 22    WI       LEVOTHYROXINE SODIUM           724862.0   39474748.0
# 23    SC  HYDROCODONE/ACETAMINOPHEN           705275.0   14990744.0
# 24    MN                 LISINOPRIL           692905.0   42774075.0
# 25    CO       LEVOTHYROXINE SODIUM           644433.0   35905871.0
# 26    OK  HYDROCODONE/ACETAMINOPHEN           638873.0   13850860.0
# 27    MS  HYDROCODONE/ACETAMINOPHEN           623289.0   12748780.0
# 28    AR  HYDROCODONE/ACETAMINOPHEN           587738.0   12091622.0
# 29    IA       LEVOTHYROXINE SODIUM           573383.0   27138647.0
# 30    OR       LEVOTHYROXINE SODIUM           571237.0   31484405.0
# 31    KS       LEVOTHYROXINE SODIUM           503645.0   23593843.0
# 32    MD                 LISINOPRIL           463341.0   27402858.0
# 33    CT       ATORVASTATIN CALCIUM           462215.0   26167110.0
# 34    WV  HYDROCODONE/ACETAMINOPHEN           400423.0    8797436.0
# 35    NE       LEVOTHYROXINE SODIUM           336322.0   14689226.0
# 36    NV  HYDROCODONE/ACETAMINOPHEN           294635.0    6712686.0
# 37    NM       LEVOTHYROXINE SODIUM           290021.0   15943445.0
# 38    UT       LEVOTHYROXINE SODIUM           253237.0   14387993.0
# 39    ID       LEVOTHYROXINE SODIUM           221413.0   12047895.0
# 40    RI                 LISINOPRIL           212772.0    9418983.0
# 41    ME                 LISINOPRIL           208297.0   12941923.0
# 42    HI       ATORVASTATIN CALCIUM           158062.0    8964750.0
# 43    SD       LEVOTHYROXINE SODIUM           157701.0    7519498.0
# 44    MT       LEVOTHYROXINE SODIUM           155249.0    7891795.0
# 45    NH       LEVOTHYROXINE SODIUM           150455.0    8029406.0
# 46    ND       LEVOTHYROXINE SODIUM           120810.0    5935446.0
# 47    DE       LEVOTHYROXINE SODIUM           100751.0    6729646.0
# 48    WY       LEVOTHYROXINE SODIUM            78676.0    3899029.0
# 49    VT                 LISINOPRIL            74747.0    4652247.0
# 50    DC        AMLODIPINE BESYLATE            69458.0    3018756.0
#
#     total_cost_millions
# 0                  78.0
# 1                  64.0
# 2                  63.0
# 3                  21.0
# 4                  44.0
# 5                  32.0
# 6                  40.0
# 7                  30.0
# 8                  28.0
# 9                  24.0
# 10                 10.0
# 11                 22.0
# 12                 26.0
# 13                  8.0
# 14                  8.0
# 15                 22.0
# 16                 18.0
# 17                 22.0
# 18                 17.0
# 19                 16.0
# 20                 13.0
# 21                  6.0
# 22                 15.0
# 23                 14.0
# 24                  6.0
# 25                 12.0
# 26                 14.0
# 27                 10.0
# 28                 11.0
# 29                 10.0
# 30                 11.0
# 31                  9.0
# 32                  4.0
# 33                 12.0
# 34                  7.0
# 35                  6.0
# 36                  6.0
# 37                  5.0
# 38                  5.0
# 39                  4.0
# 40                  1.0
# 41                  2.0
# 42                  7.0
# 43                  3.0
# 44                  3.0
# 45                  3.0
# 46                  2.0
# 47                  3.0
# 48                  1.0
# 49                  1.0
# 50                  1.0

# %%
#Added query to python variable
Most_Prescribed_DF = response2.head(51).copy()

# %%
#Reduce the column value by showing in millions
Most_Prescribed_DF["total_claim_count"] = round(Most_Prescribed_DF["total_claim_count"]/1000000 , 2)

# %%
#Reduce the column value by showingin millions
Most_Prescribed_DF["day_supply"] = round(Most_Prescribed_DF["day_supply"]/1000000, 2)

# %%
Most_Prescribed_DF
# Out:
#    state                  drug_name  total_claim_count  day_supply  \
# 0     CA       LEVOTHYROXINE SODIUM               3.84      211.73
# 1     FL       LEVOTHYROXINE SODIUM               2.98      163.38
# 2     TX  HYDROCODONE/ACETAMINOPHEN               2.83       60.40
# 3     NY        AMLODIPINE BESYLATE               2.61      123.22
# 4     PA       LEVOTHYROXINE SODIUM               2.35      109.16
# 5     OH       LEVOTHYROXINE SODIUM               1.81       93.49
# 6     MI  HYDROCODONE/ACETAMINOPHEN               1.79       39.89
# 7     NC       LEVOTHYROXINE SODIUM               1.51       68.62
# 8     IL       LEVOTHYROXINE SODIUM               1.46       74.23
# 9     TN  HYDROCODONE/ACETAMINOPHEN               1.38       29.08
# 10    GA        AMLODIPINE BESYLATE               1.28       54.75
# 11    AL  HYDROCODONE/ACETAMINOPHEN               1.21       26.75
# 12    PR       LEVOTHYROXINE SODIUM               1.14       39.27
# 13    MA                 LISINOPRIL               1.13       57.56
# 14    MO                 LISINOPRIL               1.06       50.28
# 15    IN  HYDROCODONE/ACETAMINOPHEN               1.04       21.68
# 16    KY  HYDROCODONE/ACETAMINOPHEN               0.98       22.28
# 17    NJ       LEVOTHYROXINE SODIUM               0.96       54.07
# 18    AZ       LEVOTHYROXINE SODIUM               0.87       49.73
# 19    VA       LEVOTHYROXINE SODIUM               0.84       42.34
# 20    LA  HYDROCODONE/ACETAMINOPHEN               0.80       16.27
# 21    WA                 LISINOPRIL               0.77       44.26
# 22    WI       LEVOTHYROXINE SODIUM               0.72       39.47
# 23    SC  HYDROCODONE/ACETAMINOPHEN               0.71       14.99
# 24    MN                 LISINOPRIL               0.69       42.77
# 25    CO       LEVOTHYROXINE SODIUM               0.64       35.91
# 26    OK  HYDROCODONE/ACETAMINOPHEN               0.64       13.85
# 27    MS  HYDROCODONE/ACETAMINOPHEN               0.62       12.75
# 28    AR  HYDROCODONE/ACETAMINOPHEN               0.59       12.09
# 29    IA       LEVOTHYROXINE SODIUM               0.57       27.14
# 30    OR       LEVOTHYROXINE SODIUM               0.57       31.48
# 31    KS       LEVOTHYROXINE SODIUM               0.50       23.59
# 32    MD                 LISINOPRIL               0.46       27.40
# 33    CT       ATORVASTATIN CALCIUM               0.46       26.17
# 34    WV  HYDROCODONE/ACETAMINOPHEN               0.40        8.80
# 35    NE       LEVOTHYROXINE SODIUM               0.34       14.69
# 36    NV  HYDROCODONE/ACETAMINOPHEN               0.29        6.71
# 37    NM       LEVOTHYROXINE SODIUM               0.29       15.94
# 38    UT       LEVOTHYROXINE SODIUM               0.25       14.39
# 39    ID       LEVOTHYROXINE SODIUM               0.22       12.05
# 40    RI                 LISINOPRIL               0.21        9.42
# 41    ME                 LISINOPRIL               0.21       12.94
# 42    HI       ATORVASTATIN CALCIUM               0.16        8.96
# 43    SD       LEVOTHYROXINE SODIUM               0.16        7.52
# 44    MT       LEVOTHYROXINE SODIUM               0.16        7.89
# 45    NH       LEVOTHYROXINE SODIUM               0.15        8.03
# 46    ND       LEVOTHYROXINE SODIUM               0.12        5.94
# 47    DE       LEVOTHYROXINE SODIUM               0.10        6.73
# 48    WY       LEVOTHYROXINE SODIUM               0.08        3.90
# 49    VT                 LISINOPRIL               0.07        4.65
# 50    DC        AMLODIPINE BESYLATE               0.07        3.02
#
#     total_cost_millions
# 0                  78.0
# 1                  64.0
# 2                  63.0
# 3                  21.0
# 4                  44.0
# 5                  32.0
# 6                  40.0
# 7                  30.0
# 8                  28.0
# 9                  24.0
# 10                 10.0
# 11                 22.0
# 12                 26.0
# 13                  8.0
# 14                  8.0
# 15                 22.0
# 16                 18.0
# 17                 22.0
# 18                 17.0
# 19                 16.0
# 20                 13.0
# 21                  6.0
# 22                 15.0
# 23                 14.0
# 24                  6.0
# 25                 12.0
# 26                 14.0
# 27                 10.0
# 28                 11.0
# 29                 10.0
# 30                 11.0
# 31                  9.0
# 32                  4.0
# 33                 12.0
# 34                  7.0
# 35                  6.0
# 36                  6.0
# 37                  5.0
# 38                  5.0
# 39                  4.0
# 40                  1.0
# 41                  2.0
# 42                  7.0
# 43                  3.0
# 44                  3.0
# 45                  3.0
# 46                  2.0
# 47                  3.0
# 48                  1.0
# 49                  1.0
# 50                  1.0

# %%
#I noticed alot of the same drugs appeared frequently, so I decided to group them and get the sum.
#LEVOTHYROXINE SODIUM a Hyper Thyroid medication appeared the most with the greatest cost
Most_Prescribed_DF.groupby('drug_name').sum().sort_values(by=['total_claim_count'],ascending = False)
# Out:
#                            total_claim_count  day_supply  total_cost_millions
# drug_name
# LEVOTHYROXINE SODIUM                   22.63     1160.69                449.0
# HYDROCODONE/ACETAMINOPHEN              13.28      285.54                264.0
# LISINOPRIL                              4.60      249.28                 36.0
# AMLODIPINE BESYLATE                     3.96      180.99                 32.0
# ATORVASTATIN CALCIUM                    0.62       35.13                 19.0

# %%
Group_Most_Presc_DF = Most_Prescribed_DF.groupby('drug_name').sum().sort_values(by=['total_claim_count'],ascending = False)

# %%
Group_Most_Presc_DF.plot.bar(rot=-30, subplots=True,figsize =(10,5), position=.9 );

# %%
#What are the top 5 medications prescribed in each state?



ST5query = ''' SELECT * FROM (SELECT nppes_provider_state AS state,
                                generic_name AS drug_name,
                                sum(total_claim_count),
                                RANK () OVER (PARTITION BY nppes_provider_state ORDER BY sum(total_claim_count) DESC) AS row_rank
                                FROM `bigquery-public-data.cms_medicare.part_d_prescriber_2014`
                                GROUP BY nppes_provider_state, drug_name
                                ORDER BY sum(total_claim_count) DESC
                                )
                WHERE row_rank <= 5
                ORDER BY state'''

responseST5 = medicare.query_to_pandas_safe(ST5query, max_gb_scanned=10)
responseST5.head(350)
# Out:
#     state                  drug_name   f0_  row_rank
# 0      AA                AMOXICILLIN   225         1
# 1      AA  HYDROCODONE/ACETAMINOPHEN   180         2
# 2      AA                  IBUPROFEN   155         3
# 3      AA               AZITHROMYCIN    78         4
# 4      AA         METHYLPREDNISOLONE    71         5
# ..    ...                        ...   ...       ...
# 300    ZZ  HYDROCODONE/ACETAMINOPHEN  2232         1
# 301    ZZ        AMLODIPINE BESYLATE  1076         2
# 302    ZZ                 LISINOPRIL  1046         3
# 303    ZZ                SIMVASTATIN  1041         4
# 304    ZZ                 OMEPRAZOLE   887         5
#
# [305 rows x 4 columns]

# %%
#Assign state top 5 query to python variable
state_top5_df = responseST5.head(350).copy()

# %%
#Rename column "f0_" to 'total_claims_count'
state_top5_df.rename(columns={'f0_':'total_claims_count'}, inplace=True)

# %%
state_top5_df
# Out:
#     state                  drug_name  total_claims_count  row_rank
# 0      AA                AMOXICILLIN                 225         1
# 1      AA  HYDROCODONE/ACETAMINOPHEN                 180         2
# 2      AA                  IBUPROFEN                 155         3
# 3      AA               AZITHROMYCIN                  78         4
# 4      AA         METHYLPREDNISOLONE                  71         5
# ..    ...                        ...                 ...       ...
# 300    ZZ  HYDROCODONE/ACETAMINOPHEN                2232         1
# 301    ZZ        AMLODIPINE BESYLATE                1076         2
# 302    ZZ                 LISINOPRIL                1046         3
# 303    ZZ                SIMVASTATIN                1041         4
# 304    ZZ                 OMEPRAZOLE                 887         5
#
# [305 rows x 4 columns]

# %%
#The data contains records for 61 states instead of 50. NOT SURE WHY.
state_top5_df['state'].unique()
# Out:
# array(['AA', 'AE', 'AK', 'AL', 'AP', 'AR', 'AS', 'AZ', 'CA', 'CO', 'CT',
#        'DC', 'DE', 'FL', 'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS',
#        'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT',
#        'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR',
#        'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI', 'VT',
#        'WA', 'WI', 'WV', 'WY', 'XX', 'ZZ'], dtype=object)

# %%
#What is each drugs average rank
state_top5_df.groupby('drug_name')['drug_name',"row_rank"].mean().sort_values(by=["row_rank"])
# Out:
#                               row_rank
# drug_name
# LEVOTHYROXINE SODIUM          1.943396
# HYDROCODONE/ACETAMINOPHEN     1.966667
# AMOXICILLIN                   2.000000
# LISINOPRIL                    2.622642
# CHLORHEXIDINE GLUCONATE       3.000000
# FINASTERIDE                   3.000000
# METFORMIN HCL                 3.000000
# LOSARTAN/HYDROCHLOROTHIAZIDE  3.000000
# AMLODIPINE BESYLATE           3.111111
# LOSARTAN POTASSIUM            3.333333
# IBUPROFEN                     3.500000
# SIMVASTATIN                   3.666667
# ATORVASTATIN CALCIUM          3.750000
# OMEPRAZOLE                    3.789474
# NAPROXEN                      4.000000
# GABAPENTIN                    4.000000
# AZITHROMYCIN                  4.000000
# FUROSEMIDE                    4.714286
# NIFEDIPINE                    5.000000
# PRAVASTATIN SODIUM            5.000000
# ALPRAZOLAM                    5.000000
# METOPROLOL SUCCINATE          5.000000
# METHYLPREDNISOLONE            5.000000
# HYDROCHLOROTHIAZIDE           5.000000
# METOPROLOL TARTRATE           5.000000
# TAMSULOSIN HCL                5.000000

# %%
#How frequent does each drug appear in a top 5?
state_top5_df.groupby('drug_name')['drug_name'].count().sort_values(ascending=False)
# Out:
# drug_name
# LEVOTHYROXINE SODIUM            53
# LISINOPRIL                      53
# OMEPRAZOLE                      38
# AMLODIPINE BESYLATE             36
# SIMVASTATIN                     36
# HYDROCODONE/ACETAMINOPHEN       30
# ATORVASTATIN CALCIUM            24
# FUROSEMIDE                       7
# METFORMIN HCL                    5
# AMOXICILLIN                      3
# LOSARTAN POTASSIUM               3
# FINASTERIDE                      2
# IBUPROFEN                        2
# GABAPENTIN                       1
# AZITHROMYCIN                     1
# CHLORHEXIDINE GLUCONATE          1
# TAMSULOSIN HCL                   1
# HYDROCHLOROTHIAZIDE              1
# LOSARTAN/HYDROCHLOROTHIAZIDE     1
# METHYLPREDNISOLONE               1
# METOPROLOL SUCCINATE             1
# METOPROLOL TARTRATE              1
# NAPROXEN                         1
# NIFEDIPINE                       1
# PRAVASTATIN SODIUM               1
# ALPRAZOLAM                       1
# Name: drug_name, dtype: int64

# %%
#What is CA top 5 prescribed drugs
state_top5_df[state_top5_df['state'] =="CA"]
# Out:
#    state                  drug_name  total_claims_count  row_rank
# 40    CA       LEVOTHYROXINE SODIUM             3844722         1
# 41    CA  HYDROCODONE/ACETAMINOPHEN             3740106         2
# 42    CA        AMLODIPINE BESYLATE             3728200         3
# 43    CA       ATORVASTATIN CALCIUM             3678833         4
# 44    CA                SIMVASTATIN             3392175         5

# %%
#Lets graph it!
state_top5_df[state_top5_df['state'] =="CA"].set_index('drug_name').plot.bar(y='total_claims_count',
                                                                             rot=-30, subplots=True,figsize =(10,5), 
                                                                             position=.9, stacked=True,
                                                                            colormap='Paired')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a2549cc90>],
#       dtype=object)

# %%
#What is ALABAMA top 5 prescribed drugs
state_top5_df[state_top5_df['state'] =="AL"]
# Out:
#    state                  drug_name  total_claims_count  row_rank
# 15    AL  HYDROCODONE/ACETAMINOPHEN             1214392         1
# 16    AL                 OMEPRAZOLE              762739         2
# 17    AL       LEVOTHYROXINE SODIUM              733869         3
# 18    AL        AMLODIPINE BESYLATE              708626         4
# 19    AL                 LISINOPRIL              608947         5

# %%
#Write max prescriptions table to csv file
#max_presc_by_state.to_csv('/Users/phillliprashaad/Documents/states.csv')

# %%
#Write state_top5_df to csv file
#state_top5_df.to_csv('/Users/phillliprashaad/Desktop/Galvanzie_DSI/Capstone_1/Health Care/import_tables/state_top5.csv')

# %%
#Import population data into dataframe
pop_df = pd.read_csv('/Users/phillliprashaad/Desktop/Galvanzie_DSI/Capstone_1/Health Care/import_tables/region_pop_2.csv')

# %%
pop_df
# Out:
#     SUMLEV  REGION_dig REGION_name  DIVISION_dig        DIVISION_name  \
# 0       10         0.0         ALL           0.0         NON DIVISION
# 1       20         1.0   Northeast           0.0         NON DIVISION
# 2       20         2.0     Midwest           0.0         NON DIVISION
# 3       20         3.0       South           0.0         NON DIVISION
# 4       20         4.0        West           0.0         NON DIVISION
# 5       40         3.0       South           6.0  East South Central
# 6       40         4.0        West           9.0             Pacific
# 7       40         4.0        West           8.0             Mountain
# 8       40         3.0       South           7.0  West South Central
# 9       40         4.0        West           9.0             Pacific
# 10      40         4.0        West           8.0             Mountain
# 11      40         1.0   Northeast           1.0         New England
# 12      40         3.0       South           5.0       South Atlantic
# 13      40         3.0       South           5.0       South Atlantic
# 14      40         3.0       South           5.0       South Atlantic
# 15      40         3.0       South           5.0       South Atlantic
# 16      40         4.0        West           9.0             Pacific
# 17      40         4.0        West           8.0             Mountain
# 18      40         2.0     Midwest           3.0  East North Central
# 19      40         2.0     Midwest           3.0  East North Central
# 20      40         2.0     Midwest           4.0  West North Central
# 21      40         2.0     Midwest           4.0  West North Central
# 22      40         3.0       South           6.0  East South Central
# 23      40         3.0       South           7.0  West South Central
# 24      40         1.0   Northeast           1.0         New England
# 25      40         3.0       South           5.0       South Atlantic
# 26      40         1.0   Northeast           1.0         New England
# 27      40         2.0     Midwest           3.0  East North Central
# 28      40         2.0     Midwest           4.0  West North Central
# 29      40         3.0       South           6.0  East South Central
# 30      40         2.0     Midwest           4.0  West North Central
# 31      40         4.0        West           8.0             Mountain
# 32      40         2.0     Midwest           4.0  West North Central
# 33      40         4.0        West           8.0             Mountain
# 34      40         1.0   Northeast           1.0         New England
# 35      40         1.0   Northeast           2.0      Middle Atlantic
# 36      40         4.0        West           8.0             Mountain
# 37      40         1.0   Northeast           2.0      Middle Atlantic
# 38      40         3.0       South           5.0       South Atlantic
# 39      40         2.0     Midwest           4.0  West North Central
# 40      40         2.0     Midwest           3.0  East North Central
# 41      40         3.0       South           7.0  West South Central
# 42      40         4.0        West           9.0             Pacific
# 43      40         1.0   Northeast           2.0      Middle Atlantic
# 44      40         1.0   Northeast           1.0         New England
# 45      40         3.0       South           5.0       South Atlantic
# 46      40         2.0     Midwest           4.0  West North Central
# 47      40         3.0       South           6.0  East South Central
# 48      40         3.0       South           7.0  West South Central
# 49      40         4.0        West           8.0             Mountain
# 50      40         1.0   Northeast           1.0         New England
# 51      40         3.0       South           5.0       South Atlantic
# 52      40         4.0        West           9.0             Pacific
# 53      40         3.0       South           5.0       South Atlantic
# 54      40         2.0     Midwest           3.0  East North Central
# 55      40         4.0        West           8.0             Mountain
# 56      40         NaN   Territory           NaN            Territory
#
#     STATE_dig  STATE_abb                  NAME  CENSUS2010POP  \
# 0           0        NaN         United States      308745538
# 1           0        NaN      Northeast Region       55317240
# 2           0        NaN        Midwest Region       66927001
# 3           0        NaN          South Region      114555744
# 4           0        NaN           West Region       71945553
# 5           1         AL               Alabama        4779736
# 6           2         AK                Alaska         710231
# 7           4         AZ               Arizona        6392017
# 8           5         AR              Arkansas        2915918
# 9           6         CA            California       37253956
# 10          8         CO              Colorado        5029196
# 11          9         CT           Connecticut        3574097
# 12         10         DE              Delaware         897934
# 13         11       D.C.  District of Columbia         601723
# 14         12         FL               Florida       18801310
# 15         13         GA               Georgia        9687653
# 16         15         HI                Hawaii        1360301
# 17         16         ID                 Idaho        1567582
# 18         17         IL              Illinois       12830632
# 19         18         IN               Indiana        6483802
# 20         19         IA                  Iowa        3046355
# 21         20         KS                Kansas        2853118
# 22         21         KY              Kentucky        4339367
# 23         22         LA             Louisiana        4533372
# 24         23         ME                 Maine        1328361
# 25         24         MD              Maryland        5773552
# 26         25         MA         Massachusetts        6547629
# 27         26         MI              Michigan        9883640
# 28         27         MN             Minnesota        5303925
# 29         28         MS           Mississippi        2967297
# 30         29         MO              Missouri        5988927
# 31         30         MT               Montana         989415
# 32         31         NE              Nebraska        1826341
# 33         32         NV                Nevada        2700551
# 34         33         NH         New Hampshire        1316470
# 35         34         NJ            New Jersey        8791894
# 36         35         NM            New Mexico        2059179
# 37         36         NY              New York       19378102
# 38         37         NC        North Carolina        9535483
# 39         38         ND          North Dakota         672591
# 40         39         OH                  Ohio       11536504
# 41         40         OK              Oklahoma        3751351
# 42         41         OR                Oregon        3831074
# 43         42         PA          Pennsylvania       12702379
# 44         44         RI          Rhode Island        1052567
# 45         45         SC        South Carolina        4625364
# 46         46         SD          South Dakota         814180
# 47         47         TN             Tennessee        6346105
# 48         48         TX                 Texas       25145561
# 49         49         UT                  Utah        2763885
# 50         50         VT               Vermont         625741
# 51         51         VA              Virginia        8001024
# 52         53         WA            Washington        6724540
# 53         54         WV         West Virginia        1852994
# 54         55         WI             Wisconsin        5686986
# 55         56         WY               Wyoming         563626
# 56         72  Territory           Puerto Rico        3725789
#
#     ESTIMATESBASE2010  ...  RDOMESTICMIG2019  RNETMIG2011  RNETMIG2012  \
# 0           308758105  ...          0.000000     2.493773     2.682083
# 1            55318443  ...         -5.254530     0.887909    -0.038355
# 2            66929725  ...         -2.365881    -0.963930    -0.973943
# 3           114563030  ...          3.261349     5.130513     5.850458
# 4            71946907  ...          0.614245     2.723344     3.062896
# 5             4780125  ...          1.917501     0.578434     1.186314
# 6              710249  ...        -12.929847     0.587728     1.416798
# 7             6392288  ...         12.609078     4.278167     6.899802
# 8             2916031  ...          0.834503     3.294766     0.827785
# 9            37254519  ...         -5.151429     1.276797     1.495016
# 10            5029319  ...          5.473351     7.795086     7.512104
# 11            3574147  ...         -6.181756     0.242487    -0.409588
# 12             897937  ...          7.179090     4.848991     4.843736
# 13             601767  ...         -3.130827    16.246186    16.091188
# 14           18804564  ...          6.268893     8.925935    10.561534
# 15            9688729  ...          4.702641     2.953730     3.703741
# 16            1360307  ...         -9.742408     4.622184     5.086274
# 17            1567657  ...         15.468110     1.311712     0.507040
# 18           12831572  ...         -8.268277    -2.635449    -3.393092
# 19            6484051  ...          0.595336     0.090413    -0.464677
# 20            3046871  ...         -1.589863     1.941776    -0.178103
# 21            2853123  ...         -4.242985    -1.362919     0.469895
# 22            4339333  ...         -0.345174     2.033035     0.963892
# 23            4533487  ...         -5.595970     2.073649     0.776105
# 24            1328358  ...          4.929062     0.827587    -0.298191
# 25            5773794  ...         -3.917566     3.612639     3.257604
# 26            6547785  ...         -4.395455     4.286075     4.593951
# 27            9884116  ...         -2.370446    -1.951728    -0.914581
# 28            5303927  ...          0.011560     1.305812     0.394301
# 29            2968130  ...         -3.605740    -0.822957    -1.872690
# 30            5988950  ...         -0.115833    -0.993982    -0.889266
# 31             989407  ...          5.657818     3.754503     3.343163
# 32            1826305  ...         -2.186516     0.577623     1.178135
# 33            2700677  ...         14.148840    -1.942334     6.142878
# 34            1316462  ...          3.294294     0.918480     1.773536
# 35            8791978  ...         -5.509389    -0.789559    -2.093922
# 36            2059199  ...         -1.019675     2.163570    -1.726107
# 37           19378144  ...         -9.267874     0.310701    -0.963243
# 38            9535751  ...          6.453184     4.365764     5.258187
# 39             672576  ...         -1.666950    10.715179    16.716664
# 40           11536751  ...         -1.105564    -1.900104    -1.878444
# 41            3751582  ...          0.967937     3.614843     3.929176
# 42            3831079  ...          6.148133     5.617206     3.885453
# 43           12702868  ...         -1.530139     1.552816     0.503431
# 44            1052964  ...         -3.036388    -1.483198    -0.632746
# 45            4625366  ...         10.365420     4.472883     6.269019
# 46             814198  ...          1.093369     3.550552     6.513612
# 47            6346276  ...          5.295128     3.999341     5.375475
# 48           25146091  ...          4.361336     7.456866     8.764683
# 49            2763891  ...          4.902266     0.776426     1.451720
# 50             625737  ...         -1.092645     0.897099    -2.464212
# 51            8001049  ...         -1.072502     4.396815     5.054575
# 52            6724540  ...          4.950999     6.906540     4.878573
# 53            1853018  ...         -3.933336     1.901071     0.828402
# 54            5687285  ...         -0.247295    -0.777306    -0.834993
# 55             563775  ...         -1.750320    -0.379930    10.019202
# 56            3726157  ...          0.000000   -14.533549   -14.982183
#
#     RNETMIG2013  RNETMIG2014  RNETMIG2015  RNETMIG2016  RNETMIG2017  \
# 0      2.636187     2.921500     3.260435     3.252788     2.871957
# 1     -0.469783    -0.986097    -2.061965    -2.490484    -1.837048
# 2     -0.006924    -0.762969    -1.388437    -1.241784    -0.557370
# 3      5.292073     6.161501     7.277358     7.150074     6.198168
# 4      3.162262     4.026429     4.987285     5.261078     4.021194
# 5      1.522549     0.563489     0.626357     0.745172     1.090366
# 6     -0.955359   -11.460949    -7.997118    -3.897349   -10.992765
# 7      6.376679     9.168478     9.597577    11.964782    10.878879
# 8      0.057853    -0.091449     1.075446     1.486269     2.009593
# 9      1.649031     2.203551     1.984957     0.500044    -0.629909
# 10     8.492707     9.117126    12.902098    10.634370     8.032033
# 11    -1.671074    -1.941757    -3.756242    -4.137741    -2.616537
# 12     6.150901     6.436204     6.713849     5.382576     6.252676
# 13    16.784065    10.637447    12.296969     8.092770     6.538613
# 14    11.079296    13.202431    16.491494    18.258305    15.616389
# 15     1.655839     3.977992     5.719232     7.107500     5.868999
# 16     3.508325    -1.314307     0.317282    -1.303336    -6.875992
# 17     3.321347     6.047525     5.947892    13.145583    15.602505
# 18    -3.135896    -5.111479    -6.028806    -6.905914    -6.649699
# 19     1.323932     0.286119    -0.934854     0.694721     1.050827
# 20     2.301114     1.888640     0.567227     0.053100     0.618850
# 21    -2.140359    -2.254523    -1.321287    -3.615554    -4.291045
# 22     1.536343    -0.478285     0.484598     0.754274     1.766390
# 23     0.975774    -0.241894     0.051995    -1.440045    -5.342778
# 24     0.722210     2.493115    -0.473902     3.478746     4.083380
# 25     1.717501     1.118979     0.275479    -1.383949    -0.238959
# 26     5.051165     4.922265     2.612559     2.069639     3.476476
# 27    -0.504689    -0.537824    -1.527775     0.057639     0.780980
# 28     1.783298     1.689162     0.829590     2.493826     3.270817
# 29    -1.003595    -2.134072    -3.047029    -2.403450    -1.672565
# 30    -0.154827    -0.458795     0.122692    -0.033720     1.182732
# 31     6.905091     5.146804     5.514670     7.574829     9.217801
# 32     1.185936     1.783368     0.927174     2.058525     0.545850
# 33     6.565982     9.763662    12.403407    12.971212    13.758376
# 34     0.608106     4.345173     2.061662     4.098322     4.916959
# 35    -2.140785    -2.868381    -3.080788    -3.261555    -1.374719
# 36    -2.408853    -5.738621    -4.161423    -2.261703    -2.592619
# 37    -1.791701    -3.130145    -4.174457    -5.379085    -6.127425
# 38     5.932176     5.279168     6.612526     9.049543     8.311209
# 39    22.949497    14.080772    15.315123    -6.451442    -5.683143
# 40     0.335559    -0.055998    -0.500254    -0.335715     0.934403
# 41     5.064632     2.750342     4.513278     0.852239    -1.553900
# 42     3.054669     7.349495    10.517812    15.722384    11.095753
# 43    -0.058645    -0.161708    -0.927692    -0.973673     0.284710
# 44    -0.701521    -0.066319    -0.587121    -0.319949    -1.596256
# 45     7.244263     9.607938    11.600778    11.241529    11.026696
# 46     4.626817     1.715693     0.454461     5.211464     6.635312
# 47     3.586588     4.550168     5.190219     6.072290     7.675288
# 48     7.132347    10.003069    10.644301     8.369711     6.510551
# 49     3.053374     1.683429     3.858608     9.016381     8.864528
# 50    -0.352951    -2.290191    -0.028790    -2.507861     1.543268
# 51     3.455999     2.208119     1.521520     1.273915     2.382525
# 52     4.473256     7.799901    10.408549    13.254138    12.865626
# 53    -0.825701    -1.779985    -2.551781    -4.330978    -5.336583
# 54     0.066337    -0.421473    -1.068755    -0.628600     0.729926
# 55     4.863492    -4.816885     0.207166    -7.182252   -13.322489
# 56   -13.803542   -18.263032   -18.480599   -19.848533   -23.228903
#
#     RNETMIG2018  RNETMIG2019
# 0      2.153911     1.818059
# 1     -2.134447    -2.859713
# 2     -0.922755    -1.111173
# 3      5.225519     5.203720
# 4      3.044951     2.312083
# 5      1.773786     2.483744
# 6    -13.859140   -12.031221
# 7     12.962934    13.687161
# 8      0.958896     0.923429
# 9     -2.130954    -3.276681
# 10     9.410633     7.311426
# 11    -1.533419    -2.728391
# 12     7.631475     7.254377
# 13     3.481678     0.569887
# 14    12.657811    10.420286
# 15     5.434037     6.127537
# 16    -5.974019    -6.207022
# 17    13.921714    15.562524
# 18    -7.328003    -6.755453
# 19     2.846129     2.737025
# 20    -0.656262    -0.744961
# 21    -2.581066    -2.833807
# 22     0.251531    -0.173819
# 23    -5.248091    -4.942803
# 24     4.968453     5.564109
# 25    -1.416954    -1.432606
# 26     1.619656    -0.268309
# 27    -0.300042    -1.053932
# 28     2.832317     1.632242
# 29    -4.275713    -3.125981
# 30     0.500152     0.781953
# 31     5.947528     5.960244
# 32    -0.028114    -0.479272
# 33    15.559809    13.831198
# 34     3.756866     4.729513
# 35    -2.792216    -3.113650
# 36    -1.819561    -0.281652
# 37    -6.406096    -6.920598
# 38     8.409553     7.812475
# 39    -1.711806    -0.415751
# 40     0.081934    -0.287861
# 41    -0.013974     2.103529
# 42     7.451555     6.932692
# 43     0.855382    -0.004375
# 44     1.782437     0.406111
# 45    11.161729    11.484168
# 46     1.345082     1.567465
# 47     7.543825     6.661665
# 48     5.448428     6.618846
# 49     6.983989     6.656804
# 50     0.440457    -0.479033
# 51     0.786684     0.673014
# 52     9.468242     8.135276
# 53    -4.484031    -4.127417
# 54     0.763089     0.327262
# 55    -5.725739    -0.819814
# 56   -37.860351     2.421463
#
# [57 rows x 154 columns]

# %%
#The medication data is from 2014 so I want to look at the population data from the same year

pop_2014_df = pop_df[['REGION_name','DIVISION_name','STATE_abb','NAME', 'POPESTIMATE2014','NPOPCHG_2014', 'BIRTHS2014']].copy()

# %%
#Scale columns in table by dividing 1m. It makes plot look cleaner.
pop_2014_df[['POPESTIMATE2014','NPOPCHG_2014','BIRTHS2014' ]] /= 1e6

# %%
#Round to the 3rd decimal place
pop_2014_df.round(3)
# Out:
#    REGION_name        DIVISION_name  STATE_abb                  NAME  \
# 0          ALL              Country        NaN         United States
# 1    Northeast               Region        NaN      Northeast Region
# 2      Midwest               Region        NaN        Midwest Region
# 3        South               Region        NaN          South Region
# 4         West               Region        NaN           West Region
# 5        South  East South Central          AL               Alabama
# 6         West             Pacific          AK                Alaska
# 7         West             Mountain         AZ               Arizona
# 8        South  West South Central          AR              Arkansas
# 9         West             Pacific          CA            California
# 10        West             Mountain         CO              Colorado
# 11   Northeast         New England          CT           Connecticut
# 12       South       South Atlantic         DE              Delaware
# 13       South       South Atlantic       D.C.  District of Columbia
# 14       South       South Atlantic         FL               Florida
# 15       South       South Atlantic         GA               Georgia
# 16        West             Pacific          HI                Hawaii
# 17        West             Mountain         ID                 Idaho
# 18     Midwest  East North Central          IL              Illinois
# 19     Midwest  East North Central          IN               Indiana
# 20     Midwest  West North Central          IA                  Iowa
# 21     Midwest  West North Central          KS                Kansas
# 22       South  East South Central          KY              Kentucky
# 23       South  West South Central          LA             Louisiana
# 24   Northeast         New England          ME                 Maine
# 25       South       South Atlantic         MD              Maryland
# 26   Northeast         New England          MA         Massachusetts
# 27     Midwest  East North Central          MI              Michigan
# 28     Midwest  West North Central          MN             Minnesota
# 29       South  East South Central          MS           Mississippi
# 30     Midwest  West North Central          MO              Missouri
# 31        West             Mountain         MT               Montana
# 32     Midwest  West North Central          NE              Nebraska
# 33        West             Mountain         NV                Nevada
# 34   Northeast         New England          NH         New Hampshire
# 35   Northeast      Middle Atlantic         NJ            New Jersey
# 36        West             Mountain         NM            New Mexico
# 37   Northeast      Middle Atlantic         NY              New York
# 38       South       South Atlantic         NC        North Carolina
# 39     Midwest  West North Central          ND          North Dakota
# 40     Midwest  East North Central          OH                  Ohio
# 41       South  West South Central          OK              Oklahoma
# 42        West             Pacific          OR                Oregon
# 43   Northeast      Middle Atlantic         PA          Pennsylvania
# 44   Northeast         New England          RI          Rhode Island
# 45       South       South Atlantic         SC        South Carolina
# 46     Midwest  West North Central          SD          South Dakota
# 47       South  East South Central          TN             Tennessee
# 48       South  West South Central          TX                 Texas
# 49        West             Mountain         UT                  Utah
# 50   Northeast         New England          VT               Vermont
# 51       South       South Atlantic         VA              Virginia
# 52        West             Pacific          WA            Washington
# 53       South       South Atlantic         WV         West Virginia
# 54     Midwest  East North Central          WI             Wisconsin
# 55        West             Mountain         WY               Wyoming
# 56   Territory            Territory  Territory           Puerto Rico
#
#     POPESTIMATE2014  NPOPCHG_2014  BIRTHS2014
# 0           318.301         2.307       3.963
# 1            56.006         0.104       0.632
# 2            67.745         0.185       0.837
# 3           119.624         1.260       1.525
# 4            74.926         0.759       0.969
# 5             4.842         0.012       0.059
# 6             0.736        -0.001       0.011
# 7             6.730         0.098       0.086
# 8             2.967         0.008       0.038
# 9            38.597         0.336       0.499
# 10            5.350         0.081       0.066
# 11            3.595        -0.000       0.036
# 12            0.932         0.009       0.011
# 13            0.662         0.012       0.009
# 14           19.846         0.300       0.218
# 15           10.067         0.095       0.130
# 16            1.415         0.006       0.019
# 17            1.631         0.020       0.022
# 18           12.884        -0.011       0.158
# 19            6.594         0.025       0.084
# 20            3.109         0.016       0.039
# 21            2.900         0.007       0.039
# 22            4.414         0.010       0.056
# 23            4.644         0.019       0.064
# 24            1.331         0.003       0.013
# 25            5.957         0.034       0.073
# 26            6.763         0.049       0.072
# 27            9.930         0.017       0.115
# 28            5.451         0.038       0.070
# 29            2.990         0.002       0.039
# 30            6.056         0.015       0.076
# 31            1.022         0.008       0.012
# 32            1.879         0.014       0.026
# 33            2.818         0.042       0.035
# 34            1.333         0.007       0.012
# 35            8.865         0.008       0.103
# 36            2.090        -0.003       0.026
# 37           19.651         0.027       0.237
# 38            9.933         0.090       0.120
# 39            0.737         0.015       0.011
# 40           11.603         0.026       0.140
# 41            3.878         0.025       0.053
# 42            3.963         0.041       0.045
# 43           12.788         0.012       0.142
# 44            1.056         0.001       0.011
# 45            4.824         0.060       0.057
# 46            0.849         0.007       0.012
# 47            6.541         0.047       0.080
# 48           26.964         0.484       0.394
# 49            2.937         0.039       0.051
# 50            0.625        -0.001       0.006
# 51            8.311         0.059       0.103
# 52            7.055         0.091       0.087
# 53            1.849        -0.004       0.021
# 54            5.752         0.015       0.067
# 55            0.583         0.000       0.008
# 56            3.535        -0.058       0.036

# %%
#Create a dataframe that groups and sums the population by Division

division_2014_df = pop_2014_df[pop_2014_df['DIVISION_name']!='NON DIVISION'].groupby('DIVISION_name').sum().round(3).sort_values(by='POPESTIMATE2014')

division_2014_df.plot.barh(y='POPESTIMATE2014',rot=30, subplots=True,figsize =(15,10), position=.9, stacked=True,colormap='Paired');

# %%
division_2014_df.describe()
# Out:
#        POPESTIMATE2014  NPOPCHG_2014  BIRTHS2014
# count        10.000000      10.00000   10.000000
# mean         32.183600       0.22500    0.400000
# std          18.687823       0.24625    0.232933
# min           3.535000      -0.05800    0.036000
# 25%          19.336750       0.06100    0.244000
# 50%          30.807000       0.09250    0.395000
# 75%          45.397500       0.42625    0.559000
# max          62.382000       0.65300    0.742000

# %%
#Now lets merge State top 5 table with the 2014 population table

joined_df_merge = state_top5_df.merge(pop_2014_df, how='left', 
                                         left_on='state', 
                                         right_on='STATE_abb',
                                         suffixes=('','_region'))

# %%
#Scale total_claims_count column values
joined_df_merge['total_claims_count'] /= 1e6

# %%
joined_df_merge[joined_df_merge['state']=='AL']
# Out:
#    state                  drug_name  total_claims_count  row_rank REGION_name  \
# 15    AL  HYDROCODONE/ACETAMINOPHEN            1.214392         1       South
# 16    AL                 OMEPRAZOLE            0.762739         2       South
# 17    AL       LEVOTHYROXINE SODIUM            0.733869         3       South
# 18    AL        AMLODIPINE BESYLATE            0.708626         4       South
# 19    AL                 LISINOPRIL            0.608947         5       South
#
#           DIVISION_name STATE_abb     NAME  POPESTIMATE2014  NPOPCHG_2014  \
# 15  East South Central         AL  Alabama         4.841799      0.011718
# 16  East South Central         AL  Alabama         4.841799      0.011718
# 17  East South Central         AL  Alabama         4.841799      0.011718
# 18  East South Central         AL  Alabama         4.841799      0.011718
# 19  East South Central         AL  Alabama         4.841799      0.011718
#
#     BIRTHS2014
# 15    0.058903
# 16    0.058903
# 17    0.058903
# 18    0.058903
# 19    0.058903

# %%
#Heatmap shows the correlations between variables. 
#There is a very high correlation between population size and total claims count
plt.subplots(figsize=(12,12))
sns.heatmap(joined_df_merge.corr(), annot=True, center=1);

# %%
joined_df_merge.columns
# Out:
# Index(['state', 'drug_name', 'total_claims_count', 'row_rank', 'REGION_name',
#        'DIVISION_name', 'STATE_abb', 'NAME', 'POPESTIMATE2014', 'NPOPCHG_2014',
#        'BIRTHS2014'],
#       dtype='object')

# %%
pd.plotting.scatter_matrix(joined_df_merge, alpha=0.2, figsize=(10,10), diagonal='kde');

# %%
pd.plotting.scatter_matrix?
